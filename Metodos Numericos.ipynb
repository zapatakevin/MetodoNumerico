# %%
#IMPORTAMOS "tkinter"
from tkinter import *
import tkinter
from tkinter import ttk
from math import *
import numpy as np
import math
from numpy import *
import sympy as sy
#from pylab import *
import matplotlib.pyplot as plt

def Metodobise():
    # INGRESO
    e = ecuacion.get()
    a = float(extremoin.get())
    b = float(extremosu.get())
    error = float(er.get())

    # PROCEDIMIENTO
    def fx(e):
        return e
    tabla = []
    tramo = b-a
    fa = fx(a)
    fb = fx(b)
    i = 0
    while (tramo>error):
        c = (a+b)/2
        fc = fx(c)
        tabla.append([i,a,b,c,fa,fb,fc,tramo])
        i = i + 1

        cambia = np.sign(fa)*np.sign(fc)
        if (cambia<0):
            b = c
            fb = fc
        else:
            a=c
            fa = fc
            tramo = abs(b-a)
    c = (a+b)/2
    fc = fx(c)
    tabla.append([i ,a,b,c,fa,fc,fb,tramo])
    tabla = np.array(tabla)

    raiz = c
    # SALIDA
    np.set_printoptions(precision = 4)
    print('[i,   a ,  b,    Xm,   f(a),  f(b), f(Xm), Error]')
    # print(tabla)

    # Tabla con formato
    n=len(tabla)
    for i in range(0,n,1):
        unafila = tabla[i]
        formato = '{:.0f}'+' '+(len(unafila)-1)*'{:.3f} '
        unafila = formato.format(*unafila)
        print(unafila)
        r.set(unafila)
    print('raiz: ',raiz)
    r.set('Raiz '+ str(raiz))
    print("Ecuacion ",ecuacion.get())

def graficabisec():
    e = ecuacion.get()
    a = float(extremoin.get())
    b = float(extremosu.get())
    def fx(e):
        return  eval(e)
    print(e)
    x=linspace(a,b,100)
    plt.plot(x, fx(e),'-',color='black')
    show()
    resultado=numero.get()+5
    print("RESULTADO: ",resultado)
def newtow():
    x=sy.symbols('x')
    e = ecuacion.get()
    x0 = float(extremoin.get())
    error = float(er.get())
    xr=x0
    def fx(x):
        return sy.sympify(e)

    #primera derivada de la funcion
    derivada=sy.diff(e,x)
    #dfx = lambda x: -1-exp(-x)
    # PROCEDIMIENTO
    tabla = []
    tramo = abs(2*error)
    xi = x0
    contador=0
    print('xi', '      xnuevo','                     error')
    while (tramo>=error):
        contador+=1
        xra=xr
        newton=x-(fx(x)/derivada)
        xr=newton.evalf(subs={x: xr})
       # xnuevo = xi - fx(xi)/dfx(xi)
        tramo  = abs(xr-xra)
        tabla.append([contador,xr,tramo])
        xi = xr
        print(contador,"\t",xr,"\t",tramo)
    # convierte la lista a un arreglo.
    tabla = np.array(tabla)
    n = len(tabla)
    # SALIDA
    np.set_printoptions(precision = 4)
    print('\nraiz en: ', xi)
    print('con error de: ',tramo)
    print('Con ',contador, 'iteraciones')
    r.set('Raiz '+ str(xi))
def reglafal():
    # INGRESO
    n =ecuacion.get()
    def fx(x):
        return eval(n)
    a = float(extremoin.get())
    b = float(extremosu.get())
    tolera =float(er.get())
    
    # PROCEDIMIENTO
    tabla = []
    tramo = abs(b-a)
    fa = fx(a)
    fb = fx(b)
    while not(tramo<=tolera):
        c = b - fb*(a-b)/(fa-fb)
        fc = fx(c)
        tabla.append([a,c,b,fa,fc,fb,tramo])
        cambio = np.sign(fa)*np.sign(fc)
        if cambio>0:
            tramo = abs(c-a)
            a = c
            fa = fc
        else:
            tramo = abs(b-c)
            b = c
            fb = fc
            
    tabla = np.array(tabla)
    ntabla = len(tabla)
    
    # SALIDA
    np.set_printoptions(precision=4)
    for i in range(0,ntabla,1):
        print('iteración:  ',i)
        print('[a,c,b]:    ', tabla[i,0:3])
        print('[fa,fc,fb]: ', tabla[i,3:6])
        print('[tramo]:    ', tabla[i,6])
        
    print('raiz:  ',c)
    r.set(c)
    print('error: ',tramo)
    
    
def secante():
    
    def secante_tabla(fx,xa,tolera):
        dx = 4*tolera
        xb = xa + dx
        tramo = dx
        tabla = []
        while (tramo>=tolera):
            fa = fx(xa)
            fb = fx(xb)
            xc = xa - fa*(xb-xa)/(fb-fa)
            tramo = abs(xc-xa)
            
            tabla.append([xa,xb,xc,tramo])
            xb = xa
            xa = xc
    
        tabla = np.array(tabla)
        return(tabla)
    
    # PROGRAMA ---------------------
    # INGRESO
    n= ecuacion.get()
    def fx(x):
        return eval(n)
    a  = float(extremoin.get())
    b  = float(extremosu.get())
    xa = 1.5
    tolera = float(er.get())
    tramos = 100
    
    # PROCEDIMIENTO
    tabla = secante_tabla(fx,xa,tolera)
    n = len(tabla)
    raiz = tabla[n-1,2]
    
    # SALIDA
    np.set_printoptions(precision=4)
    print('[xa ,\t xb , \t xc , \t tramo]')
    for i in range(0,n,1):
        print(tabla[i])
    print('raiz en: ', raiz)
    r.set('raiz:  '+str(raiz))
def RaizMultiple():
    # INGRESO
    #fx  = lambda x: exp(-x)-x
    x=sy.symbols('x')
    x0 = float(extremoin.get())
    error = float(er.get())
    xr=x0
    e = ecuacion.get()
    def fx(x):
        return sy.sympify(e)
    #primera derivada de la funcion
    derivada=sy.diff(e,x)
    ddf= sy.diff(e,x,x)
    #dfx = lambda x: -1-exp(-x)
    # PROCEDIMIENTO
    tabla = []
    tramo = abs(2*error)
    xi = x0
    contador=0
    print('xi', '      xnuevo','                    error')
    while (tramo>=error):
        contador+=1
        xra=xr
        newton=x-(fx(x)*derivada)/(derivada* derivada-fx(x)*ddf)  #newtor matriz   x-(fx(x)/derivada) 
        xr=newton.evalf(subs={x: xr})
       # xnuevo = xi - fx(xi)/dfx(xi)
        tramo  = abs(xr-xra)
        tabla.append([contador,xr,tramo])
        xi = xr
        print(contador,"\t",xr,"\t",tramo)
    # convierte la lista a un arreglo.
    tabla = np.array(tabla)
    n = len(tabla)
    # SALIDA
    np.set_printoptions(precision = 4)
    print('\nraiz en: ', xi)
    r.set('Raiz '+ str(xi))
    print('con error de: ',tramo)
    print('Con ',contador, 'iteraciones')

def Derivacion():
    # INGRESO
    if opcion.get()==1:
        x=sy.symbols('x')
        x0 =float(extremoin.get())
        h=float(er.get())
        e = ecuacion.get()
        def fx(x):
            return sy.sympify(e)
        #primera derivada de la funcion
        derivada=sy.diff(e,x)
        #numerico=x-(fx(x)/derivada)  
        #numerico=fx(x0+h)-fx(x0)/h
        l=x0+h
        numerico1=fx(x)
        numerico2=fx(x)
        resultado=numerico1.evalf(subs={x: l})
        resdos=numerico2.evalf(subs={x: x0})
        n=resultado-resdos
        divisor= n/h
        derivadar=derivada.evalf(subs={x: x0})
        absoluto=abs(derivadar-divisor)
        print(absoluto)
        print("Derivada de dos puntos \n"+"f(x) "+ str(divisor) , str(derivadar),str(absoluto))
        r.set('Derivada de dos puntos \n'+'f(x) '+ str(divisor ) +'\n '+ str(derivadar )+ ' '+str( absoluto))
    elif opcion.get()==2:
        # INGRESO
        #fx  = lambda x: exp(-x)-x
        x=sy.symbols('x')
        x0 =float(extremoin.get())
        h =float(er.get())
        e = ecuacion.get()
        def fx(x):
            return sy.sympify(e)
        derivada=sy.diff(e,x)
        v1=x0-2*h
        v4=x0+2*h
        v2=x0-h
        v3=x0+h
        numerico1=fx(x)
        numerico2=fx(x)
        numerico3=fx(x)
        f1=numerico1.evalf(subs={x: v1})
        f2=numerico2.evalf(subs={x: v2})
        f3=numerico3.evalf(subs={x: x0})
        f4=numerico3.evalf(subs={x: v3})
        f5=numerico3.evalf(subs={x: v4})
        v1 =1/(2*h)*(f1-(4*f2)+(3*f3))
        v2 =1/(2*h)*(-3*f3+(4*f4)-f5)
        v3 =1/(2*h)*(-f2+f4)
        print("Derivada de tres puntos \n"+"f(x) ", str(v1) ,str(v2) ,str(v3))
        r.set('Derivada de tres puntos \n'+'f(x) '+ str(v1) +'\n '+ str(v2)+' '+str(v3))
    elif opcion.get()==3:
        # INGRESO
        #fx  = lambda x: exp(-x)-x
        x=sy.symbols('x')
        x0 =float(extremoin.get())
        h =float(er.get())
        e = ecuacion.get()
        def fx(x):
            return sy.sympify(e)
        derivada=sy.diff(e,x)
        v1=x0-2*h
        v2=x0-h
        v3=x0
        v4=x0+h
        v5=x0+2*h
        numerico1=fx(x)
        f1=numerico1.evalf(subs={x: v1})
        f2=numerico1.evalf(subs={x: v2})
        f3=numerico1.evalf(subs={x: v3})
        f4=numerico1.evalf(subs={x: v4})
        f5=numerico1.evalf(subs={x: v5})
        v1 =(f1-8*f2+8*f4-f5)/(12*h)
        print("Derivada de Cinco puntos \n"+"f(x) ", str(v1))
        r.set('Derivada de Cinco puntos \n'+'f(x) '+ str(v1))



def trapecio():
    if opcion.get()==1:
        f =ecuacion.get()
        funcion = sy.sympify(f)
        a = float(extremoin.get())
        b = float(extremosu.get())
        m = int(er.get())
        h = (b-a)/float(m)
        s = 0
        n = 0
        a_evaluado = 0
        b_evaluado = 0
        print('i,  x    ,  f(x)   ')
        for i in range(1,m):
            n = a + (i*h)
            n_evaluado = funcion.evalf(subs = {"x" : n}) #evalua n en la funcion descrita
            s = s + n_evaluado
            v= n_evaluado*2
            print(str(i)+" "+ str(n) +" " + str(n_evaluado) +" " + str(v))
            r.set(str(i)+" "+ str(n) +" " + str(n_evaluado) +" " + str(s))
        a_evaluado = funcion.evalf(subs = {"x" : a}) #evalua a en la funcion descrita, lo mismo con b en la siguiente linea
        b_evaluado = funcion.evalf(subs = {"x" : b})
        resul = h/2 * (a_evaluado + 2*s + b_evaluado)
        print("Integral "+str(resul)) #el primer parametro debe ser la funcion en expresion literal
        r.set("Integral "+str(resul))
    elif opcion.get()==2:
        # INGRESO:
        f =ecuacion.get()
        def fx(x):
            return  eval(f)
        # intervalo de integración
        a = float(extremoin.get())
        b = float(extremosu.get())
        tramos =int(er.get())

        # PROCEDIMIENTO
        # Tarea: validar tramos par

        # Regla de Simpson 1/3
        h = (b-a)/tramos
        xi = a
        area = 0
        for i in range(0,tramos,2):
            deltaA = (h/3)*(fx(xi)+4*fx(xi+h)+fx(xi+2*h))
            area = area + deltaA
            xi = xi + 2*h
            print(str(i)+" "+str(xi)+" "+str(fx(xi))+" "+ str(2*fx(xi)))
        # SALIDA
        print('tramos:', tramos)
        r.set('Integral: '+str (area))
    elif opcion.get()==3:
        f = ecuacion.get()
        def funcion(x):
            return  eval(f)
        # aqui se deben ingresar los valores de la integral
        b=float(extremoin.get()) #b
        a=float(extremosu.get()) #a
        n=float(er.get()) #tomamos el valor de n como 3 para este metodo

        # La formula es (3/8)(h)((Fx0)+3(fx1)+3(fx2)+(fx3))

        # se calcula h para la formula
        h= (a-b)/n  # (a-b) /n  recordando que n=3
        # se calculan x0,x1,x2,x3 con las sigueientes formulas
        x0= b #x0=b
        x1=x0+h #b+h
        x2=x1+h 
        x3=x2+h 
        # ya calculadas las x, calculamos las fx usando la funcion
        fx0= funcion(x0)
        fx1=funcion(x1)
        fx2=funcion(x2)
        fx3=funcion(x3)
        print(str(fx1)+" "+str(fx3))
        # ya tenemos todo lo necesario para sustituirlo en la formula de la linea 14

        resultado= (h)*(3/8)*((fx0)+3*(fx1)+3*(fx2)+(fx3))
        print("Integral: ",resultado)
        r.set('Integral: '+str (resultado))
        
        
def divid5():
    resultado=numero.get()/5
    print("RESULTADO: ",resultado)

#VENTANA PRINCIPAL.
root = tkinter.Tk()
style = ttk.Style()
settings = {"TNotebook.Tab": {"configure": {"padding": [5, 1],
                                            "background": "#52AFFA"
                                           },
                              "map": {"background": [("selected", "#C70039"), 
                                                     ("active", "#fc9292")],
                                      "foreground": [("selected", "#ffffff"),
                                                     ("active", "#000000")]

                                     }
                              }
           }  


style.theme_create("mi_estilo", parent="alt", settings=settings)
style.theme_use("mi_estilo")
root.title("Ventana de Metodos")
root.geometry("750x350")
ecuacion = StringVar()
extremoin = StringVar()
extremosu = StringVar()
er = StringVar()
r = StringVar()

#INCLUIMOS PANEL PARA LAS PESTAÑAS.
nb = ttk.Notebook(root)
nb.pack(fill='both',expand='yes')

#CREAMOS PESTAÑAS
p1 = ttk.Frame(nb)
p2 = ttk.Frame(nb)
p3 = ttk.Frame(nb)
p4 = ttk.Frame(nb)
p5 = ttk.Frame(nb)
p6 = ttk.Frame(nb)
p7 = ttk.Frame(nb)

#ELEMENTOS PESTAÑA Método de bisección.
lblTitulo = Label(p1,text="Método de bisección ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=180, height=30)
Button(p1, text='Calcular',bg='light blue',command=Metodobise).place(x=225,y=210)
Button(p1, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p1, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p1, textvariable=extremoin).place(x=190,y=80)
Entry(p1, textvariable=extremosu).place(x=190,y=110)
Entry(p1, textvariable=er).place(x=190,y=140)
Entry(p1, textvariable=r,bg="cyan").place(x=190,y=170,width=190, height=20)
lblNum1 = Label(p1,text="Ecuación: ",bg="#D0FFFB")
lblNum2 = Label(p1,text="Extremo inferior: ",bg="#D0FFFB")
lblNum3 = Label(p1,text="Extremo superior: ",bg="#D0FFFB")
lblNum4 = Label(p1,text="Error: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum3.place(x=90,y=110,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)



#ELEMENTOS PESTAÑA regla falsa
lblTitulo = Label(p2,text="Método de falsa posición ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=210, height=30)
Button(p2, text='Calcular',bg='light blue',command=reglafal).place(x=225,y=210)
Button(p2, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p2, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p2, textvariable=extremoin).place(x=190,y=80)
Entry(p2, textvariable=extremosu).place(x=190,y=110)
Entry(p2, textvariable=er).place(x=190,y=140)
Entry(p2, textvariable=r,bg="cyan").place(x=190,y=170,width=190, height=20)
lblNum1 = Label(p2,text="Ecuación: ",bg="#D0FFFB")
lblNum2 = Label(p2,text="Extremo inferior: ",bg="#D0FFFB")
lblNum3 = Label(p2,text="Extremo superior: ",bg="#D0FFFB")
lblNum4 = Label(p2,text="Error: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum3.place(x=90,y=110,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)


#ELEMENTOS PESTAÑA Newtowm.
lblTitulo = Label(p3,text="Método de Newton ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=210, height=30)
Button(p3, text='Calcular',bg='light blue',command=newtow).place(x=225,y=210)
Button(p3, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p3, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p3, textvariable=extremoin).place(x=190,y=80)
Entry(p3, textvariable=er).place(x=190,y=140)
Entry(p3, textvariable=r,bg="cyan").place(x=190,y=170,width=190, height=20)
lblNum1 = Label(p3,text="Ecuación: ",bg="#D0FFFB")
lblNum2 = Label(p3,text="Extremo inferior: ",bg="#D0FFFB")
lblNum4 = Label(p3,text="Error: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum3.place(x=90,y=110,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)

#ELEMENTOS PESTAÑA Secante.
lblTitulo = Label(p4,text="Método de secante ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=180, height=30)
Button(p4, text='Calcular',bg='light blue',command=secante).place(x=225,y=210)
Button(p4, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p4, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p4, textvariable=extremoin).place(x=190,y=80)
Entry(p4, textvariable=extremosu).place(x=190,y=110)
Entry(p4, textvariable=er).place(x=190,y=140)
Entry(p4, textvariable=r,bg="cyan").place(x=190,y=170,width=190, height=20)
lblNum1 = Label(p4,text="Ecuación: ",bg="#D0FFFB")
lblNum2 = Label(p4,text="Extremo inferior: ",bg="#D0FFFB")
lblNum3 = Label(p4,text="Extremo superior: ",bg="#D0FFFB")
lblNum4 = Label(p4,text="Error: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum3.place(x=90,y=110,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)


#ELEMENTOS PESTAÑA Raiz Multiple.
lblTitulo = Label(p5,text="Raiz Multiple ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=180, height=30)
Button(p5, text='Calcular',bg='light blue',command=RaizMultiple).place(x=225,y=210)
Button(p5, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p5, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p5, textvariable=extremoin).place(x=190,y=80)
Entry(p5, textvariable=er).place(x=190,y=140)
Entry(p5, textvariable=r,bg="cyan").place(x=190,y=170,width=190, height=20)
lblNum1 = Label(p5,text="Ecuación: ",bg="#D0FFFB")
lblNum2 = Label(p5,text="valor inicial: ",bg="#D0FFFB")
lblNum4 = Label(p5,text="Error: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)

#ELEMENTOS PESTAÑA Derivadas.
lblTitulo = Label(p6,text="Derivadas ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=180, height=30)
Button(p6, text='Calcular',bg='light blue',command=Derivacion).place(x=450,y=80)
#Button(p6, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p6, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p6, textvariable=extremoin).place(x=190,y=80)
Entry(p6, textvariable=er).place(x=190,y=110)
Entry(p6, textvariable=r,bg="cyan").place(x=100,y=140,width=470, height=50)
lblNum1 = Label(p6,text="Ecuación: F(x) ",bg="#D0FFFB")
lblNum2 = Label(p6,text="X0: ",bg="#D0FFFB")
lblNum4 = Label(p6,text="h: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum4.place(x=90,y=110,width=100, height=20)
opcion = IntVar()
Radiobutton(p6,text="Derivada de dos puntos",variable=opcion, value=1).place(x=225,y=210)
Radiobutton(p6,text="Derivada de tres puntos",variable=opcion, value=2).place(x=225,y=240)
Radiobutton(p6,text="Derivada de Cinco puntos",variable=opcion, value=3).place(x=225,y=270)

#ELEMENTOS PESTAÑA Trapecio.
lblTitulo = Label(p7,text="Integracion ",bg="#D9D5F5", font=("Helvetica", 14))
lblTitulo.place(x=150,y=0,width=180, height=30)
Button(p7, text='Calcular',bg='light blue',command=trapecio).place(x=450,y=80)
#Button(p6, text='Graficar',bg='light blue',command=graficabisec).place(x=225,y=240)
Entry(p7, textvariable=ecuacion).place(x=190,y=50,width=190, height=20)
Entry(p7, textvariable=extremoin).place(x=190,y=80)
Entry(p7, textvariable=extremosu).place(x=190,y=110)
Entry(p7, textvariable=er).place(x=190,y=140)
Entry(p7, textvariable=r,bg="cyan").place(x=100,y=170,width=470, height=50)
lblNum1 = Label(p7,text="Ecuación: F(x) ",bg="#D0FFFB")
lblNum2 = Label(p7,text="a: ",bg="#D0FFFB")
lblNum3 = Label(p7,text="b: ",bg="#D0FFFB")
lblNum4 = Label(p7,text="n: ",bg="#D0FFFB")
lblNum1.place(x=90,y=50,width=100, height=20)
lblNum2.place(x=90,y=80,width=100, height=20)
lblNum3.place(x=90,y=110,width=100, height=20)
lblNum4.place(x=90,y=140,width=100, height=20)
opcion = IntVar()
Radiobutton(p7,text="Regla de trapecio",variable=opcion, value=1).place(x=225,y=220)
Radiobutton(p7,text="Simpson 1/3",variable=opcion, value=2).place(x=225,y=250)
Radiobutton(p7,text="Simpson 3/8",variable=opcion, value=3).place(x=225,y=280)



#AGREGAMOS PESTAÑAS CREADAS
nb.add(p1,text='Método de bisección')
nb.add(p2,text='Método de falsa posición ')
nb.add(p3,text='Método Newton - Raphson')
nb.add(p4,text='Método Secante')
nb.add(p5,text='Raiz Multiple')
nb.add(p6,text='Derivadas')
nb.add(p7,text='Integracion')
#nb.add(p5,text='Divid5')
root.mainloop()
# Out:
# i,  x    ,  f(x)
# 1 2.4 -0.0843034608442231 -0.168606921688446
# 2 2.8000000000000003 -0.994167756939140 -1.98833551387828
# Integral -0.101428451716167
# 0 2.004696673189824 0.7475822113942668 1.4951644227885337
# 2 2.009393346379648 0.7421374392399317 1.4842748784798634
# 4 2.0140900195694718 0.7366023106391232 1.4732046212782464
# 6 2.0187866927592957 0.7309759015489805 1.461951803097961
# 8 2.0234833659491196 0.7252572921219752 1.4505145842439504
# 10 2.0281800391389435 0.7194455672073568 1.4388911344147135
# 12 2.0328767123287674 0.7135398168677641 1.4270796337355283
# 14 2.0375733855185914 0.7075391369112823 1.4150782738225647
# 16 2.0422700587084153 0.7014426294392212 1.4028852588784424
# 18 2.046966731898239 0.6952494034098915 1.390498806819783
# 20 2.051663405088063 0.6889585752186634 1.3779171504373269
# 22 2.056360078277887 0.6825692692945757 1.3651385385891515
# 24 2.061056751467711 0.6760806187137807 1.3521612374275613
# ...

# %%
import tkinter as tk

from tkinter import *

class windowclass():

        def __init__(self,master):
                self.master = master
                self.frame = tk.Frame(master)
                self.lbl = Label(master , text = "Label u")
                self.lbl.pack()
                self.btn = Button(master , text = "Button" , command = self.command )
                self.btn.pack()
                self.frame.pack()

        def command(self):
                print ("Button is pressed!")

                self.newWindow = tk.Toplevel(self.master)
                self.app = windowclass1(self.newWindow)

class windowclass1():

        def __init__(self , master):
                self.master = master
                self.frame = tk.Frame(master)
                master.title("a")
                self.quitButton = tk.Button(self.frame, text = 'Quit', width = 25 , command = self.close_window)
                self.quitButton.pack()
                self.frame.pack()


        def close_window(self):
                self.master.destroy()


root = Tk()

root.title("window")

root.geometry("350x50")

cls = windowclass(root)

root.mainloop()
